# %% [markdown]
# <a href="https://colab.research.google.com/github/rajv33rbhosal3/ACP-s/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bs_men = [130,85,90,150,149,88,93,115,135]
bs_women = [100,102,103,104,105,106,107,108,109,110]
type = [bs_men,bs_women]
color = ['r','g']
label = ['men','women']
plt.xlabel('bs range')
plt.ylabel('patients')
bins = [80,100,125,150]
plt.hist(type,bins = bins, rwidth = 0.95,color = color,orientation = 'horizontal')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
